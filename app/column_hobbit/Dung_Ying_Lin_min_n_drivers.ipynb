# %%
from Dung_Ying_Lin_tasks import Dung_Ying_Lin_tasks
tasks = Dung_Ying_Lin_tasks()
print(len(tasks))
# Out:
# 190

# %%
from idle_time_calculation import idle_time_calculation
from idle_time_solver import IdleTimeSolver
from min_n_drivers_solver import MinNDriverSolver


solver = IdleTimeSolver(
    T_idle= 300,
    T_drive= 360,
    T_all= 660,
    tasks=tasks, max_iterations=10)
idletime_intial = 0
for pattern in solver.patterns:
    idletime_intial += idle_time_calculation(pattern, tasks)
print(idletime_intial)
# Out:
# 2831

# %%
solver.solve()
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 190 rows, 95 columns and 190 nonzeros
# Model fingerprint: 0xbd868f0b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 190 rows and 95 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.5000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.500000000e+01
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# ...

# %%
solver.final_n_drivers
# Out:
# 95

# %%
listA = {3}
if 1 not in listA:
    print("hello")
# Out:
# hello

# %%
current_time = 0
for i in range(len(solver.x_final.x)):
    if solver.x_final[i].x == 1:
        current_time+=idle_time_calculation(solver.patterns[i], tasks)
print(current_time)
# Out:
# 2831

# %%
solver.bonus_init()
#solver.fix_n_drivers = solver.final_n_drivers+2
solver.solve_idle()
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 191 rows, 105 columns and 333 nonzeros
# Model fingerprint: 0x6f7012fc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 191 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8310000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.831000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# ...

# %%
print(solver.patterns)
len(solver.patterns)
# Out:
# [[0, 24, 37, 46], [1, 21, 38], [2, 25, 48], [3, 26, 49, 60], [4, 29, 54], [5, 27, 50, 116], [6, 39, 55], [7, 36, 58], [8, 30, 51], [9, 28, 52], [10, 31, 59], [11, 32, 45, 79], [12, 40, 63], [13, 33, 47], [14, 34, 53, 131], [15, 35, 56], [16, 41, 61], [17, 42, 62, 89], [18, 43, 57, 93], [19, 44, 71], [20, 64, 98], [22, 65, 85], [23, 66, 87], [67, 97, 129], [68, 96, 122], [69, 99], [70, 100, 121], [72, 108, 137], [73, 101, 124], [74, 120], [75, 113, 135], [76, 107], [77, 109, 133], [78, 114, 130], [80, 123], [81, 125], [82, 115, 136], [83, 110], [84, 117, 138], [86, 126], [88, 127], [90, 134], [91, 128], [92, 139], [94, 132], [95, 140], [102, 141], [103, 142], [104, 143], [105, 144], [106, 145], [111, 146], [112, 147], [118, 148], [119, 149], [150], [151], [152], [153], [154], [155], [156], [157], [158], [159], [160], [161], [162], [163], [164], [165], [166], [167], [168], [169], [170], [171], [172], [173], [174], [175], [176], [177], [178], [179], [180], [181], [182], [183], [184], [1
# ...
